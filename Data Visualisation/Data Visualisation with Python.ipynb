# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [1,2,3]
y = [1,4,9]
z = [10,5,0]
plt.plot(x,y)
plt.plot(x,z)
plt.title("Test PLot")
plt.xlabel("x")
plt.ylabel("y and z")
plt.legend(["this is y","this is z"]) #legend() takes lists as argument
plt.show()

# %%
sample_data = pd.read_csv('sample_data.csv')  #the data is loaded by the pandas module and is assigned to the variable

# %%
sample_data   #0,1,2,3 are just the indices of the rows
# Out:
#    column_a  column_b  column_c
# 0         1         1        10
# 1         2         4         8
# 2         3         9         6
# 3         4        16         4
# 4         5        25         2

# %%
type(sample_data)   #it is of data frame type that is defined by module pandas and Dataframe is used to contain a piece of information like the above ones
# Out:
# pandas.core.frame.DataFrame

# %%
sample_data.column_c  #to retrieve individual column
# Out:
# 0    10
# 1     8
# 2     6
# 3     4
# 4     2
# Name: column_c, dtype: int64

# %%
type(sample_data.column_c)  #this is basically a series type defined by panda module and is used to store series of values
# Out:
# pandas.core.series.Series

# %%
sample_data.column_c.iloc[1]
# Out:
# 8

# %%
data = pd.read_excel('2012-13.xlsx')

# %%
data
# Out:
#                                         District-Name  \
# 0                                                 NaN
# 1                                                 NaN
# 2   AHMADABAD                                     ...
# 3   AMRELI                                        ...
# 4   ANAND                                         ...
# 5   BANAS KANTHA                                  ...
# 6   BHARUCH                                       ...
# 7   BHAVNAGAR                                     ...
# 8   DOHAD                                         ...
# 9   GANDHINAGAR                                   ...
# 10  JAMNAGAR                                      ...
# 11  JUNAGADH                                      ...
# 12  KACHCHH                                       ...
# 13  KHEDA                                         ...
# 14  MAHESANA                                      ...
# 15  NARMADA                                       ...
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt 
data = pd.read_csv('countries.csv')
plt.plot(data)
plt.title("Countries Graph")
plt.legend(["this is x","this is y"]) #legend() takes lists as argument
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-c0ca11b44398> in <module>
#       2 from matplotlib import pyplot as plt
#       3 data = pd.read_csv('countries.csv')
# ----> 4 plt.plot(data)
#       5 plt.title("Countries Graph")
#       6 plt.legend(["this is x","this is y"]) #legend() takes lists as argument
#
# G:\Anaconda\Anaconda Installation\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# G:\Anaconda\Anaconda Installation\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...

# %%
x = [1,2,3]
y = [1,4,9]
z = [10,5,0]
plt.plot(x,y)
plt.plot(x,z)
plt.title("Test PLot")
plt.xlabel("x")
plt.ylabel("y and z")
plt.legend(["this is y","this is z"]) #legend() takes lists as argument
plt.show()

# %%
import pandas as pd     #pd is nickname, we use pandas for importing excel and csv files
from matplotlib import pyplot as plt   #from matplotlib package we are importing pyplot as plt for making our charts 
x = [1,2,3]
y = [1,4,9]
plt.plot(x,y)
plt.title('Test Plot')
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
import pandas as pd     #pd is nickname, we use pandas for importing excel and csv files
from matplotlib import pyplot as plt   #from matplotlib package we are importing pyplot as plt for making our charts 
x = [1,2,3]
y = [1,4,9]
plt.plot(x,y)
plt.title('Test Plot')
plt.xlabel("x")
plt.ylabel("y")
plt.show()
